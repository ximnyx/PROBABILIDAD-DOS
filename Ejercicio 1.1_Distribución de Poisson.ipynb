# %% [markdown]
# # xɪᴍᴇɴᴀ ꜱᴀʀᴀí ᴄᴏʀᴅᴇʀᴏ ᴄʀᴜᴢ | ᴘʀᴏʙᴀʙɪʟɪᴅᴀᴅ ɪɪ | 4𝟤𝟨

# %% [markdown]
# ## Ejercicio 1.1

# %% [markdown]
# Realiza una exploración analítica de la distribución de Poisson, denotada por **Poisson(λ)**, con **λ>0**.
#
# En tu desarrollo, explica con claridad su origen, su interpretación como modelo de conteo, su función de masa de probabilidad, su función de distribución, sus propiedades fundamentales y algunas de sus medidas descriptivas más importantes.

# %% [markdown]
# ### ... Un poco de historia 👀
# Poisson fue un matemático francés del siglo XIX. Fue alumno de Laplace y Lagrange, cuyo talento para las matemáticas se hizo evidente desde muy joven. La contribución de Poisson está reconocida por un grabado en la Torre Eiffel que lleva su nombre.
#
#
# En 1837, publicaron un trabajo detallado titulado "Investigaciones de las probabilidades de los juicios en casos penales y civiles." Este libro explicaba cómo se podía utilizar la tería de la probabilidad para describir las decisiones tomadas en los tribunales

# %% [markdown]
#     1. Explica en qué tipos de situaciones aparece la   distribución de Poisson y por qué se utiliza para modelar el número de ocurrencias de un evento en un intervalo de tiempo, espacio, longitud o área.
